# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Hands-on Lab: Interactive Visual Analytics with Folium**

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# The launch success rate may depend on many factors such as payload mass, orbit type, and so on. It may also depend on the location and proximities of a launch site, i.e., the initial position of rocket trajectories. Finding an optimal location for building a launch site certainly involves many factors and hopefully we could discover some of the factors by analyzing the existing launch site locations.

# %% [markdown]
# In the previous exploratory data analysis labs, you have visualized the SpaceX launch dataset using `matplotlib` and `seaborn` and discovered some preliminary correlations between the launch site and success rates. In this lab, you will be performing more interactive visual analytics using `Folium`.

# %% [markdown]
# ## Objectives

# %% [markdown]
# This lab contains the following tasks:
#
# *   **TASK 1:** Mark all launch sites on a map
# *   **TASK 2:** Mark the success/failed launches for each site on the map
# *   **TASK 3:** Calculate the distances between a launch site to its proximities
#
# After completed the above tasks, you should be able to find some geographical patterns about launch sites.

# %% [markdown]
# Let's first import required Python packages for this lab:

# %%
import piplite
await piplite.install(['folium'])
await piplite.install(['pandas'])

# %%
import folium
import pandas as pd

# %%
# Import folium MarkerCluster plugin
from folium.plugins import MarkerCluster
# Import folium MousePosition plugin
from folium.plugins import MousePosition
# Import folium DivIcon plugin
from folium.features import DivIcon

# %% [markdown]
# If you need to refresh your memory about folium, you may download and refer to this previous folium lab:

# %% [markdown]
# [Generating Maps with Python](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/labs/v4/DV0101EN-Exercise-Generating-Maps-in-Python.ipynb)

# %%
## Task 1: Mark all launch sites on a map# Define map centered around launch sites
spacex_map = folium.Map(location=[28.5634, -80.5768], zoom_start=5)

# List of launch sites with lat/lon
launch_sites = [
    {"name": "CCAFS SLC-40", "lat": 28.5623, "lon": -80.5774},
    {"name": "VAFB SLC-4E", "lat": 34.6321, "lon": -120.6106},
    {"name": "KSC LC-39A", "lat": 28.5721, "lon": -80.5853},
    {"name": "CCAFS LC-40", "lat": 28.5634, "lon": -80.5768}
]

# Add markers for each site
for site in launch_sites:
    folium.Marker(
        location=[site["lat"], site["lon"]],
        popup=site["name"],
        icon=folium.Icon(color='blue', icon='rocket', prefix='fa')
    ).add_to(spacex_map)

# Display the map
spacex_map
# Define map centered around launch sites
spacex_map = folium.Map(location=[28.5634, -80.5768], zoom_start=5)

# List of launch sites with lat/lon
launch_sites = [
    {"name": "CCAFS SLC-40", "lat": 28.5623, "lon": -80.5774},
    {"name": "VAFB SLC-4E", "lat": 34.6321, "lon": -120.6106},
    {"name": "KSC LC-39A", "lat": 28.5721, "lon": -80.5853},
    {"name": "CCAFS LC-40", "lat": 28.5634, "lon": -80.5768}
]

# Add markers for each site
for site in launch_sites:
    folium.Marker(
        location=[site["lat"], site["lon"]],
        popup=site["name"],
        icon=folium.Icon(color='blue', icon='rocket', prefix='fa')
    ).add_to(spacex_map)

# Display the map
spacex_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6cd0357855f495995b5ecf0e56946c7b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6cd0357855f495995b5ecf0e56946c7b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6cd0357855f495995b5ecf0e56946c7b = L.map(
#                 &quot;map_6cd0357855f495995b5ecf0e56946c7b&quot;,
#                 {
#                     center: [28.5634, -80.5768],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e5f22770c9e8ce55263bbe7f62a7110 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4e5f22770c9e8ce55263bbe7f62a7110.addTo(map_6cd0357855f495995b5ecf0e56946c7b);
#
#
#             var marker_4925c676cfb36860d49cc83c9a8af782 = L.marker(
#                 [28.5623, -80.5774],
#                 {
# }
#             ).addTo(map_6cd0357855f495995b5ecf0e56946c7b);
#
#
#             var icon_03e754ab0a5640a63e6180e9f7247224 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_4925c676cfb36860d49cc83c9a8af782.setIcon(icon_03e754ab0a5640a63e6180e9f7247224);
#
#
#         var popup_f699fca1b3d37194b7e719cc47b12d78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a4235b584614a83f93b52845ff1dff5 = $(`&lt;div id=&quot;html_2a4235b584614a83f93b52845ff1dff5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;/div&gt;`)[0];
#                 popup_f699fca1b3d37194b7e719cc47b12d78.setContent(html_2a4235b584614a83f93b52845ff1dff5);
#
#
#
#         marker_4925c676cfb36860d49cc83c9a8af782.bindPopup(popup_f699fca1b3d37194b7e719cc47b12d78)
#         ;
#
#
#
#
#             var marker_5c52a21e077ce2061df61b55051b93af = L.marker(
#                 [34.6321, -120.6106],
#                 {
# }
#             ).addTo(map_6cd0357855f495995b5ecf0e56946c7b);
#
#
#             var icon_aa68c27331aa5a6c5a7fb1fb945f9def = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_5c52a21e077ce2061df61b55051b93af.setIcon(icon_aa68c27331aa5a6c5a7fb1fb945f9def);
#
#
#         var popup_cfd7811ff9591ebf0d2aa2d40d60bac4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b476457065acafaac927dc5df839baf = $(`&lt;div id=&quot;html_9b476457065acafaac927dc5df839baf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VAFB SLC-4E&lt;/div&gt;`)[0];
#                 popup_cfd7811ff9591ebf0d2aa2d40d60bac4.setContent(html_9b476457065acafaac927dc5df839baf);
#
#
#
#         marker_5c52a21e077ce2061df61b55051b93af.bindPopup(popup_cfd7811ff9591ebf0d2aa2d40d60bac4)
#         ;
#
#
#
#
#             var marker_8144208dd238bed132f15c4c19e0f4e4 = L.marker(
#                 [28.5721, -80.5853],
#                 {
# }
#             ).addTo(map_6cd0357855f495995b5ecf0e56946c7b);
#
#
#             var icon_0496571d36c3b7144c5c14b6926724b3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_8144208dd238bed132f15c4c19e0f4e4.setIcon(icon_0496571d36c3b7144c5c14b6926724b3);
#
#
#         var popup_de59965ad50c5818f0b826f05f546acf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d239a8118f8500ca8e1f1b0e62e5e67e = $(`&lt;div id=&quot;html_d239a8118f8500ca8e1f1b0e62e5e67e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KSC LC-39A&lt;/div&gt;`)[0];
#                 popup_de59965ad50c5818f0b826f05f546acf.setContent(html_d239a8118f8500ca8e1f1b0e62e5e67e);
#
#
#
#         marker_8144208dd238bed132f15c4c19e0f4e4.bindPopup(popup_de59965ad50c5818f0b826f05f546acf)
#         ;
#
#
#
#
#             var marker_a6ca8c6431d7bf13eab5158186be7405 = L.marker(
#                 [28.5634, -80.5768],
#                 {
# }
#             ).addTo(map_6cd0357855f495995b5ecf0e56946c7b);
#
#
#             var icon_79eb212b0f59ec380b7ff3210ab36fd3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;i

# %% [markdown]
# First, let's try to add each site's location on a map using site's latitude and longitude coordinates

# %% [markdown]
# The following dataset with the name `spacex_launch_geo.csv` is an augmented dataset with latitude and longitude added for each site.

# %%
# Download and read the `spacex_launch_geo.csv`
from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'
resp = await fetch(URL)
spacex_csv_file = io.BytesIO((await resp.arrayBuffer()).to_py())
spacex_df=pd.read_csv(spacex_csv_file)

# %% [markdown]
# Now, you can take a look at what are the coordinates for each site.

# %%
# Select relevant sub-columns: `Launch Site`, `Lat(Latitude)`, `Long(Longitude)`, `class`
spacex_df = spacex_df[['Launch Site', 'Lat', 'Long', 'class']]
launch_sites_df = spacex_df.groupby(['Launch Site'], as_index=False).first()
launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]
launch_sites_df
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %% [markdown]
# Above coordinates are just plain numbers that can not give you any intuitive insights about where are those launch sites. If you are very good at geography, you can interpret those numbers directly in your mind. If not, that's fine too. Let's visualize those locations by pinning them on a map.

# %% [markdown]
# We first need to create a folium `Map` object, with an initial center location to be NASA Johnson Space Center at Houston, Texas.

# %%
# Start location is NASA Johnson Space Center
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# %% [markdown]
# We could use `folium.Circle` to add a highlighted circle area with a text label on a specific coordinate. For example,

# %%
# Create a blue circle at NASA Johnson Space Center's coordinate with a popup label showing its name
circle = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
# Create a blue circle at NASA Johnson Space Center's coordinate with a icon showing its name
marker = folium.map.Marker(
    nasa_coordinate,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0d0918f2f8f37371586941f352ba82cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0d0918f2f8f37371586941f352ba82cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0d0918f2f8f37371586941f352ba82cf = L.map(
#                 &quot;map_0d0918f2f8f37371586941f352ba82cf&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5fe22deecbc8ea8f4bbe70b23e9da853 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5fe22deecbc8ea8f4bbe70b23e9da853.addTo(map_0d0918f2f8f37371586941f352ba82cf);
#
#
#             var circle_4fa1ae5b780595d3fec3d9e8efa110f3 = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0d0918f2f8f37371586941f352ba82cf);
#
#
#         var popup_f91c7f71cd7d17cc02b3a978192c297b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df710bdbe24e862c79d1f234252e7d1e = $(`&lt;div id=&quot;html_df710bdbe24e862c79d1f234252e7d1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_f91c7f71cd7d17cc02b3a978192c297b.setContent(html_df710bdbe24e862c79d1f234252e7d1e);
#
#
#
#         circle_4fa1ae5b780595d3fec3d9e8efa110f3.bindPopup(popup_f91c7f71cd7d17cc02b3a978192c297b)
#         ;
#
#
#
#
#             var marker_8ebc92645b6b96f1be898ee027418825 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {
# }
#             ).addTo(map_0d0918f2f8f37371586941f352ba82cf);
#
#
#             var div_icon_d5e0923fddd30e158f69e74769254459 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_8ebc92645b6b96f1be898ee027418825.setIcon(div_icon_d5e0923fddd30e158f69e74769254459);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# and you should find a small yellow circle near the city of Houston and you can zoom-in to see a larger circle.

# %% [markdown]
# Now, let's add a circle for each launch site in data frame `launch_sites`

# %% [markdown]
# *TODO:*  Create and add `folium.Circle` and `folium.Marker` for each launch site on the site map

# %% [markdown]
# An example of folium.Circle:

# %% [markdown]
# `folium.Circle(coordinate, radius=1000, color='#000000', fill=True).add_child(folium.Popup(...))`

# %% [markdown]
# An example of folium.Marker:

# %% [markdown]
# `folium.map.Marker(coordinate, icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0), html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'label', ))`

# %%
# Initial the map
site_map = folium.Map(location=nasa_coordinate, zoom_start=5)
# For each launch site, add a Circle object based on its coordinate (Lat, Long) values. In addition, add Launch site name as a popup labe

# List of launch sites with lat/lon
launch_sites = [
    {"name": "CCAFS SLC-40", "lat": 28.5623, "lon": -80.5774},
    {"name": "VAFB SLC-4E", "lat": 34.6321, "lon": -120.6106},
    {"name": "KSC LC-39A", "lat": 28.5721, "lon": -80.5853},
    {"name": "CCAFS LC-40", "lat": 28.5634, "lon": -80.5768}
]

# Add circles and markers for each launch site
for site in launch_sites:
    coordinate = [site["lat"], site["lon"]]

    # Add Circle around the launch site
    folium.Circle(
        location=coordinate,
        radius=1000,  # Radius in meters
        color='#0000FF',  # Blue border color
        fill=True,
        fill_color='#3388FF'  # Lighter blue fill
    ).add_to(site_map)

    # Add text marker for the site name
    folium.Marker(
        location=coordinate,
        icon=DivIcon(
            icon_size=(20, 20),
            icon_anchor=(0, 0),
            html=f'<div style="font-size:12px; color:#d35400;"><b>{site["name"]}</b></div>'
        )
    ).add_to(site_map)

# Display the map
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7afbd23e47b581d1fedcd085229b8020 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7afbd23e47b581d1fedcd085229b8020&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7afbd23e47b581d1fedcd085229b8020 = L.map(
#                 &quot;map_7afbd23e47b581d1fedcd085229b8020&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d55659ecac169c1a461cfd831ca25c20 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d55659ecac169c1a461cfd831ca25c20.addTo(map_7afbd23e47b581d1fedcd085229b8020);
#
#
#             var circle_969030cbd4d82115d923374d2d52bace = L.circle(
#                 [28.5623, -80.5774],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0000FF&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388FF&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7afbd23e47b581d1fedcd085229b8020);
#
#
#             var marker_a0b4040c4d6489fd7dd0ec52a3fd015e = L.marker(
#                 [28.5623, -80.5774],
#                 {
# }
#             ).addTo(map_7afbd23e47b581d1fedcd085229b8020);
#
#
#             var div_icon_f988753a5b8e6565c69bf3a6cc6e1148 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size:12px; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS SLC-40\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_a0b4040c4d6489fd7dd0ec52a3fd015e.setIcon(div_icon_f988753a5b8e6565c69bf3a6cc6e1148);
#
#
#             var circle_46d479a90d5e1b53070df97553ba7614 = L.circle(
#                 [34.6321, -120.6106],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0000FF&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388FF&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7afbd23e47b581d1fedcd085229b8020);
#
#
#             var marker_534f7e48cb5d6db1cd86a39538e6bf6c = L.marker(
#                 [34.6321, -120.6106],
#                 {
# }
#             ).addTo(map_7afbd23e47b581d1fedcd085229b8020);
#
#
#             var div_icon_e9d93233d2459703b1ee329c9fe8dd08 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size:12px; color:#d35400;\&quot;\u003e\u003cb\u003eVAFB SLC-4E\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_534f7e48cb5d6db1cd86a39538e6bf6c.setIcon(div_icon_e9d93233d2459703b1ee329c9fe8dd08);
#
#
#             var circle_93321da335398ca98e6ea9f8f9c48393 = L.circle(
#                 [28.5721, -80.5853],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0000FF&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388FF&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7afbd23e47b581d1fedcd085229b8020);
#
#
#             var marker_3af77cfc3b0fdd97fb6984381d4cd1ff = L.marker(
#                 [28.5721, -80.5853],
#                 {
# }
#             ).addTo(map_7afbd23e47b581d1fedcd085229b8020);
#
#
#             var div_icon_2402c68004696686fc083927125373f8 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size:12px; color:#d35400;\&quot;\u003e\u003cb\u003eKSC LC-39A\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_3af77cfc3b0fdd97fb6984381d4cd1ff.setIcon(div_icon_2402c68004696686fc083927125373f8);
#
#
#             var circle_e699f6d5b8f6118de92165a72c110a6c = L.circle(
#                 [28.5634, -80.5768],
#                 {&quot;bubblingMouseEvents&quot;

# %% [markdown]
# The generated map with marked launch sites should look similar to the following:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_markers.png">
# </center>

# %% [markdown]
# Now, you can explore the map by zoom-in/out the marked areas
# , and try to answer the following questions:
#
# *   Are all launch sites in proximity to the Equator line?
# *   Are all launch sites in very close proximity to the coast?
#
# Also please try to explain your findings.

# %%
# Task 2: Mark the success/failed launches for each site on the map
site_map = folium.Map(location=[28.5634, -80.5768], zoom_start=5)

# Iterate through each launch record
for index, row in spacex_df.iterrows():
    #print(row)
    coordinate = [row["Lat"], row["Long"]]
    
    # Define marker color based on success or failure
    marker_color = "green" if row["class"] == 1 else "red"

    # Add marker to the map
    folium.Marker(
        location=coordinate,
        popup=f"Launch Site: {row['Launch Site']}<br>Success: {row['class']}",
        icon=folium.Icon(color=marker_color, icon="ok" if row["class"] == 1 else "remove", prefix="fa")
    ).add_to(site_map)

# Display the map
site_map
# Out:
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    0
# Name: 0, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    0
# Name: 1, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    0
# Name: 2, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    0
# Name: 3, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    0
# Name: 4, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    0
# Name: 5, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    0
# Name: 6, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    0
# Name: 7, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    0
# Name: 8, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    0
# Name: 9, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    0
# Name: 10, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    0
# Name: 11, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    0
# Name: 12, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    0
# Name: 13, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    0
# Name: 14, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    0
# Name: 15, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    0
# Name: 16, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    1
# Name: 17, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    1
# Name: 18, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    0
# Name: 19, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    1
# Name: 20, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    1
# Name: 21, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    1
# Name: 22, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    0
# Name: 23, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    1
# Name: 24, dtype: object
# Launch Site    CCAFS LC-40
# Lat              28.562302
# Long            -80.577356
# class                    1
# Name: 25, dtype: object
# Launch Site    VAFB SLC-4E
# Lat              34.632834
# Long           -120.610745
# class                    0
# Name: 26, dtype: object
# Launch Site    VAFB SLC-4E
# Lat              34.632834
# Long           -120.610745
# class                    0
# Name: 27, dtype: object
# Launch Site    VAFB SLC-4E
# Lat              34.632834
# Long           -120.610745
# class                    1
# Name: 28, dtype: object
# Launch Site    VAFB SLC-4E
# Lat              34.632834
# Long           -120.610745
# class                    1
# Name: 29, dtype: object
# Launch Site    VAFB SLC-4E
# Lat              34.632834
# Long           -120.610745
# class                    1
# Name: 30, dtype: object
# Launch Site    VAFB SLC-4E
# Lat              34.632834
# Long           -120.610745
# class                    1
# Name: 31, dtype: object
# Launch Site    VAFB SLC-4E
# Lat              34.632834
# Long           -120.610745
# class                    0
# Name: 32, dtype: object
# Launch Site    VAFB SLC-4E
# Lat              34.632834
# Long           -120.610745
# class                    0
# Name: 33, dtype: object
# Launch Site    VAFB SLC-4E
# Lat              34.632834
# Long           -120.610745
# class                    0
# Name: 34, dtype: object
# Launch Site    VAFB SLC-4E
# Lat              34.632834
# Long           -120.610745
# class                    0
# Name: 35, dtype: object
# Launch Site    KSC LC-39A
# Lat             28.573255
# Long           -80.646895
# class                   1
# Name: 36, dtype: object
# Launch Site    KSC LC-39A
# Lat             28.573255
# Long           -80.646895
# class                   0
# Name: 37, dtype: object
# Launch Site    KSC LC-39A
# Lat             28.573255
# Long           -80.646895
# class                   1
# Name: 38, dtype: object
# Launch Site    KSC LC-39A
# Lat             28.573255
# Long           -80.646895
# class                   1
# Name: 39, dtype: object
# Launch Site    KSC LC-39A
# Lat             28.573255
# Long           -80.646895
# class                   0
# Name: 40, dtype: object
# Launch Site    KSC LC-39A
# Lat             28.573255
# Long           -80.646895
# class                   1
# Name: 41, dtype: object
# Launch Site    KSC LC-39A
# Lat             28.573255
# Long           -80.646895
# class                   1
# Name: 42, dtype: object
# Launch Site    KSC LC-39A
# Lat             28.573255
# Long           -80.646895
# class                   0
# Name: 43, dtype: object
# Launch Site    KSC LC-39A
# Lat             28.573255
# Long           -80.646895
# class                   1
# Name: 44, dtype: object
# Launch Site    KSC LC-39A
# Lat             28.573255
# Long           -80.646895
# class                   1
# Name: 45, dtype: object
# Launch Site    KSC LC-39A
# Lat             28.573255
# Long           -80.646895
# class                   1
# Name: 46, dtype: object
# Launch Site    KSC LC-39A
# Lat             28.573255
# Long           -80.646895
# class                   1
# Name: 47, dtype: object
# Launch Site    KSC LC-39A
# Lat             28.573255
# Long           -80.646895
# class                   1
# Name: 48, dtype: object
# Launch Site    CCAFS SLC-40
# Lat               28.563197
# Long              -80.57682
# class                     1
# Name: 49, dtype: object
# Launch Site    CCAFS SLC-40
# Lat               28.563197
# Long              -80.57682
# class                     1
# Name: 50, dtype: object
# Launch Site    CCAFS SLC-40
# Lat               28.563197
# Long              -80.57682
# class                     0
# Name: 51, dtype: object
# Launch Site    CCAFS SLC-40
# Lat               28.563197
# Long              -80.57682
# class                     0
# Name: 52, dtype: object
# Launch Site    CCAFS SLC-40
# Lat               28.563197
# Long              -80.57682
# class                     0
# Name: 53, dtype: object
# Launch Site    CCAFS SLC-40
# Lat               28.563197
# Long              -80.57682
# class                     1
# Name: 54, dtype: object
# Launch Site    CCAFS SLC-40
# Lat               28.563197
# Long              -80.57682
# class                     0
# Name: 55, dtype: object
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe9def770a8b3108cf6351abe62d3fd6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe9def770a8b3108cf6351abe62d3fd6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe9def770a8b3108cf6351abe62d3fd6 = L.map(
#                 &quot;map_fe9def770a8b3108cf6351abe62d3fd6&quot;,
#                 {
#                     center: [28.5634, -80.5768],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d84cae6cb88e4a2b50cb62421da33c5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3d84cae6cb88e4a2b50cb62421da33c5.addTo(map_fe9def770a8b3108cf6351abe62d3fd6);
#
#
#             var marker_8b8e15225fe7d46d2349e29ca074460c = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_fe9def770a8b3108cf6351abe62d3fd6);
#
#
#             var icon_f1e52a3570ec40de49a91f5d88f0d140 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_8b8e15225fe7d46d2349e29ca074460c.setIcon(icon_f1e52a3570ec40de49a91f5d88f0d140);
#
#
#         var popup_8554c76314398bcdd7b2745f870be9a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52a8c5f1c17892a2dd0e601b1f5b517a = $(`&lt;div id=&quot;html_52a8c5f1c17892a2dd0e601b1f5b517a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site: CCAFS LC-40&lt;br&gt;Success: 0&lt;/div&gt;`)[0];
#                 popup_8554c76314398bcdd7b2745f870be9a8.setContent(html_52a8c5f1c17892a2dd0e601b1f5b517a);
#
#
#
#         marker_8b8e15225fe7d46d2349e29ca074460c.bindPopup(popup_8554c76314398bcdd7b2745f870be9a8)
#         ;
#
#
#
#
#             var marker_d2f9633c4ac9a9915966bcae2b0235ea = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_fe9def770a8b3108cf6351abe62d3fd6);
#
#
#             var icon_2bedfb8ba30d87a278f7efcbf1af8ec0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_d2f9633c4ac9a9915966bcae2b0235ea.setIcon(icon_2bedfb8ba30d87a278f7efcbf1af8ec0);
#
#
#         var popup_bfba169d1f411a164749b1a8223fac90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7eaa86425d8dc9d1cbf234b5e96aeec0 = $(`&lt;div id=&quot;html_7eaa86425d8dc9d1cbf234b5e96aeec0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site: CCAFS LC-40&lt;br&gt;Success: 0&lt;/div&gt;`)[0];
#                 popup_bfba169d1f411a164749b1a8223fac90.setContent(html_7eaa86425d8dc9d1cbf234b5e96aeec0);
#
#
#
#         marker_d2f9633c4ac9a9915966bcae2b0235ea.bindPopup(popup_bfba169d1f411a164749b1a8223fac90)
#         ;
#
#
#
#
#             var marker_97a22f752745c6b6ad2badd4edd26b66 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_fe9def770a8b3108cf6351abe62d3fd6);
#
#
#             var icon_8712788b041efe9a2135cbf6fcd7fa09 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_97a22f752745c6b6ad2badd4edd26b66.setIcon(icon_8712788b041efe9a2135cbf6fcd7fa09);
#
#
#         var popup_01f6ca6238c343560851ed05c9167bb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f123bb91958908188e334c2ca8f668e = $(`&lt;div id=&quot;html_2f123bb91958908188e334c2ca8f668e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site: CCAFS LC-40&lt;br&gt;Success: 0&lt;/div&gt;`)[0];
#                 popup_01f6ca6238c343560851ed05c9167bb5.setContent(html_2f123bb91958908188e334c2ca8f668e);
#
#
#
#         marker_97a22f752745c6b6ad2badd4edd26b66.bindPopup(popup_01f6ca6238c343560851ed05c9167bb5)
#         ;
#
#
#
#
#             var marker_f77f32b37fee7185d7448a3dec1c1554 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_fe9def770a8b3108cf6351abe62d3fd6);
#
#
#             var icon_a628a8b41eb471d85b0991d085e269bd = L.AwesomeMar

# %% [markdown]
# Next, let's try to enhance the map by adding the launch outcomes for each site, and see which sites have high success rates.
# Recall that data frame spacex_df has detailed launch records, and the `class` column indicates if this launch was successful or not

# %%
spacex_df.tail(10)
# Out:
#      Launch Site        Lat       Long  class
# 46    KSC LC-39A  28.573255 -80.646895      1
# 47    KSC LC-39A  28.573255 -80.646895      1
# 48    KSC LC-39A  28.573255 -80.646895      1
# 49  CCAFS SLC-40  28.563197 -80.576820      1
# 50  CCAFS SLC-40  28.563197 -80.576820      1
# 51  CCAFS SLC-40  28.563197 -80.576820      0
# 52  CCAFS SLC-40  28.563197 -80.576820      0
# 53  CCAFS SLC-40  28.563197 -80.576820      0
# 54  CCAFS SLC-40  28.563197 -80.576820      1
# 55  CCAFS SLC-40  28.563197 -80.576820      0

# %% [markdown]
# Next, let's create markers for all launch records.
# If a launch was successful `(class=1)`, then we use a green marker and if a launch was failed, we use a red marker `(class=0)`

# %% [markdown]
# Note that a launch only happens in one of the four launch sites, which means many launch records will have the exact same coordinate. Marker clusters can be a good way to simplify a map containing many markers having the same coordinate.

# %% [markdown]
# Let's first create a `MarkerCluster` object

# %%
marker_cluster = MarkerCluster()

# %% [markdown]
# *TODO:* Create a new column in `spacex_df` dataframe called `marker_color` to store the marker colors based on the `class` value

# %%
# Apply a function to check the value of `class` column
# If class=1, marker_color value will be green
# If class=0, marker_color value will be red

# Initialize map centered at SpaceX launch sites
spacex_map = folium.Map(location=[28.5634, -80.5768], zoom_start=5)

# Create a MarkerCluster object
marker_cluster = MarkerCluster().add_to(spacex_map)

# Create a new column to store marker colors based on 'class'
spacex_df['marker_color'] = spacex_df['class'].apply(lambda x: 'green' if x == 1 else 'red')

# %% [markdown]
# *TODO:* For each launch result in `spacex_df` data frame, add a `folium.Marker` to `marker_cluster`

# %%
# Add marker_cluster to current site_map
# Loop through the dataframe and add each launch as a marker to the cluster
for index, row in spacex_df.iterrows():
    coordinate = [row["Lat"], row["Long"]]

    # Add marker to cluster with color based on success or failure
    folium.Marker(
        location=coordinate,
        popup=f"Launch Site: {row['Launch Site']}<br>Success: {row['class']}",
        icon=folium.Icon(color=row['marker_color'], icon="ok" if row["class"] == 1 else "remove", prefix="fa")
    ).add_to(marker_cluster)

# Display the map
spacex_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f897387f055b180c13d12218b337c765 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f897387f055b180c13d12218b337c765&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f897387f055b180c13d12218b337c765 = L.map(
#                 &quot;map_f897387f055b180c13d12218b337c765&quot;,
#                 {
#                     center: [28.5634, -80.5768],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fe10a8f4cff8a5c2bd8d230ff857458c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fe10a8f4cff8a5c2bd8d230ff857458c.addTo(map_f897387f055b180c13d12218b337c765);
#
#
#             var marker_cluster_7afa0d6df9664447b43920de3a1a089f = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_a44250009d15344a332204360f2eccf6 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_7afa0d6df9664447b43920de3a1a089f);
#
#
#             var icon_364c29affcc455b9d5e8fd73b6bf52c9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_a44250009d15344a332204360f2eccf6.setIcon(icon_364c29affcc455b9d5e8fd73b6bf52c9);
#
#
#         var popup_c31de36206db2057854621917ed132d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a93f805ca689bace9788a9ad5a459ea = $(`&lt;div id=&quot;html_3a93f805ca689bace9788a9ad5a459ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site: CCAFS LC-40&lt;br&gt;Success: 0&lt;/div&gt;`)[0];
#                 popup_c31de36206db2057854621917ed132d4.setContent(html_3a93f805ca689bace9788a9ad5a459ea);
#
#
#
#         marker_a44250009d15344a332204360f2eccf6.bindPopup(popup_c31de36206db2057854621917ed132d4)
#         ;
#
#
#
#
#             var marker_81cf9029a03f7431dbe4f244ac5bf9de = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_7afa0d6df9664447b43920de3a1a089f);
#
#
#             var icon_9c7b24861dfe6ee8de5432586f66ffd4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_81cf9029a03f7431dbe4f244ac5bf9de.setIcon(icon_9c7b24861dfe6ee8de5432586f66ffd4);
#
#
#         var popup_4aa9be22b1a4bd5965da9f02914697d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc323414d0154ebb9118e2e5c32b1735 = $(`&lt;div id=&quot;html_cc323414d0154ebb9118e2e5c32b1735&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site: CCAFS LC-40&lt;br&gt;Success: 0&lt;/div&gt;`)[0];
#                 popup_4aa9be22b1a4bd5965da9f02914697d7.setContent(html_cc323414d0154ebb9118e2e5c32b1735);
#
#
#
#         marker_81cf9029a03f7431dbe4f244ac5bf9de.bindPopup(popup_4aa9be22b1a4bd5965da9f02914697d7)
#         ;
#
#
#
#
#             var marker_bdc3d9b6d8b97b40fad8f7f5358dec1b = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_7afa0d6df9664447b43920de3a1a089f);
#
#
#             var icon_a4072f948c4ce0a450cab775bb0629e0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_bdc3d9b6d8b97b40fad8f7f5358dec1b.setIcon(icon_a4072f948c4ce0a450cab775bb0629e0);
#
#
#         var popup_4f33cb59f7101f019ceec88bafafde55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d18606e301f6c45a58a9f0426137a36 = $(`&lt;div id=&quot;html_8d18606e301f6c45a58a9f0426137a36&quot; style=&quot;width: 100.0%; heigh

# %% [markdown]
# Your updated map may look like the following screenshots:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_cluster.png">
# </center>

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_cluster_zoomed.png">
# </center>

# %% [markdown]
# From the color-labeled markers in marker clusters, you should be able to easily identify which launch sites have relatively high success rates.

# %%
# TASK 3: Calculate the distances between a launch site to its proximities

# %% [markdown]
# Next, we need to explore and analyze the proximities of launch sites.

# %% [markdown]
# Let's first add a `MousePosition` on the map to get coordinate for a mouse over a point on the map. As such, while you are exploring the map, you can easily find the coordinates of any points of interests (such as railway)

# %%
# Add Mouse Position to get the coordinate (Lat, Long) for a mouse over on the map
formatter = "function(num) {return L.Util.formatNum(num, 5);};"
mouse_position = MousePosition(
    position='topright',
    separator=' Long: ',
    empty_string='NaN',
    lng_first=False,
    num_digits=20,
    prefix='Lat:',
    lat_formatter=formatter,
    lng_formatter=formatter,
)

site_map.add_child(mouse_position)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe9def770a8b3108cf6351abe62d3fd6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe9def770a8b3108cf6351abe62d3fd6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe9def770a8b3108cf6351abe62d3fd6 = L.map(
#                 &quot;map_fe9def770a8b3108cf6351abe62d3fd6&quot;,
#                 {
#                     center: [28.5634, -80.5768],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d84cae6cb88e4a2b50cb62421da33c5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3d84cae6cb88e4a2b50cb62421da33c5.addTo(map_fe9def770a8b3108cf6351abe62d3fd6);
#
#
#             var marker_8b8e15225fe7d46d2349e29ca074460c = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_fe9def770a8b3108cf6351abe62d3fd6);
#
#
#             var icon_f1e52a3570ec40de49a91f5d88f0d140 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_8b8e15225fe7d46d2349e29ca074460c.setIcon(icon_f1e52a3570ec40de49a91f5d88f0d140);
#
#
#         var popup_8554c76314398bcdd7b2745f870be9a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52a8c5f1c17892a2dd0e601b1f5b517a = $(`&lt;div id=&quot;html_52a8c5f1c17892a2dd0e601b1f5b517a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site: CCAFS LC-40&lt;br&gt;Success: 0&lt;/div&gt;`)[0];
#                 popup_8554c76314398bcdd7b2745f870be9a8.setContent(html_52a8c5f1c17892a2dd0e601b1f5b517a);
#
#
#
#         marker_8b8e15225fe7d46d2349e29ca074460c.bindPopup(popup_8554c76314398bcdd7b2745f870be9a8)
#         ;
#
#
#
#
#             var marker_d2f9633c4ac9a9915966bcae2b0235ea = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_fe9def770a8b3108cf6351abe62d3fd6);
#
#
#             var icon_2bedfb8ba30d87a278f7efcbf1af8ec0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_d2f9633c4ac9a9915966bcae2b0235ea.setIcon(icon_2bedfb8ba30d87a278f7efcbf1af8ec0);
#
#
#         var popup_bfba169d1f411a164749b1a8223fac90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7eaa86425d8dc9d1cbf234b5e96aeec0 = $(`&lt;div id=&quot;html_7eaa86425d8dc9d1cbf234b5e96aeec0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site: CCAFS LC-40&lt;br&gt;Success: 0&lt;/div&gt;`)[0];
#                 popup_bfba169d1f411a164749b1a8223fac90.setContent(html_7eaa86425d8dc9d1cbf234b5e96aeec0);
#
#
#
#         marker_d2f9633c4ac9a9915966bcae2b0235ea.bindPopup(popup_bfba169d1f411a164749b1a8223fac90)
#         ;
#
#
#
#
#             var marker_97a22f752745c6b6ad2badd4edd26b66 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_fe9def770a8b3108cf6351abe62d3fd6);
#
#
#             var icon_8712788b041efe9a2135cbf6fcd7fa09 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_97a22f752745c6b6ad2badd4edd26b66.setIcon(icon_8712788b041efe9a2135cbf6fcd7fa09);
#
#
#         var popup_01f6ca6238c343560851ed05c9167bb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f123bb91958908188e334c2ca8f668e = $(`&lt;div id=&quot;html_2f123bb91958908188e334c2ca8f668e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site: CCAFS LC-40&lt;br&gt;Success: 0&lt;/div&gt;`)[0];
#                 popup_01f6ca6238c343560851ed05c9167bb5.setContent(html_2f123bb91958908188e334c2ca8f668e);
#
#
#
#         marker_97a22f752745c6b6ad2badd4edd26b66.bindPopup(popup_01f6ca6238c343560851ed05c9167bb5)
#         ;

# %% [markdown]
# Now zoom in to a launch site and explore its proximity to see if you can easily find any railway, highway, coastline, etc. Move your mouse to these points and mark down their coordinates (shown on the top-left) in order to the distance to the launch site.

# %% [markdown]
# Now zoom in to a launch site and explore its proximity to see if you can easily find any railway, highway, coastline, etc. Move your mouse to these points and mark down their coordinates (shown on the top-left) in order to the distance to the launch site.

# %%
from math import sin, cos, sqrt, atan2, radians

def calculate_distance(lat1, lon1, lat2, lon2):
    # approximate radius of earth in km
    R = 6373.0

    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    return distance

# %% [markdown]
# *TODO:* Mark down a point on the closest coastline using MousePosition and calculate the distance between the coastline point and the launch site.

# %%
# find coordinate of the closet coastline
# e.g.,: Lat: 28.56367  Lon: -80.57163
# distance_coastline = calculate_distance(launch_site_lat, launch_site_lon, coastline_lat, coastline_lon)

# %%
# Create and add a folium.Marker on your selected closest coastline point on the map
# Display the distance between coastline point and launch site using the icon property 
# for example
# distance_marker = folium.Marker(
#    coordinate,
#    icon=DivIcon(
#        icon_size=(20,20),
#        icon_anchor=(0,0),
#        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance),
#        )
#    )

# %% [markdown]
# *TODO:* Draw a `PolyLine` between a launch site to the selected coastline point

# %%
# Create a `folium.PolyLine` object using the coastline coordinates and launch site coordinate
# lines=folium.PolyLine(locations=coordinates, weight=1)
railway_location = (28.5721, -80.5853)  # Example railway coordinate
highway_location = (34.6321, -120.6106)  # Example highway coordinate

# Iterate over each launch site and calculate distances
for site in launch_sites:
    launch_coord = (site["lat"], site["lon"])
    
    # Draw a line from launch site to railway
    folium.PolyLine(
        locations=[launch_coord, railway_location], 
        color="blue", 
        weight=2.5, 
        opacity=1
    ).add_to(site_map)
    
    # Draw a line from launch site to highway
    folium.PolyLine(
        locations=[launch_coord, highway_location], 
        color="red", 
        weight=2.5, 
        opacity=1
    ).add_to(site_map)
    
    distance_to_railway = calculate_distance(launch_coord[0],launch_coord[1],railway_location[0],railway_location[1])
    distance_to_highway = calculate_distance(launch_coord[0],launch_coord[1],highway_location[0],highway_location[1])
    
    print(f"Launch Site: {site['name']}")
    print(f"Distance to Railway: {distance_to_railway:.2f} km")
    print(f"Distance to Highway: {distance_to_highway:.2f} km")
    print("-" * 40)

site_map
#site_map.add_child(lines)
# Out:
# Launch Site: CCAFS SLC-40
# Distance to Railway: 1.34 km
# Distance to Highway: 3827.03 km
# ----------------------------------------
# Launch Site: VAFB SLC-4E
# Distance to Railway: 3825.92 km
# Distance to Highway: 0.00 km
# ----------------------------------------
# Launch Site: KSC LC-39A
# Distance to Railway: 0.00 km
# Distance to Highway: 3825.92 km
# ----------------------------------------
# Launch Site: CCAFS LC-40
# Distance to Railway: 1.28 km
# Distance to Highway: 3827.04 km
# ----------------------------------------
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe9def770a8b3108cf6351abe62d3fd6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe9def770a8b3108cf6351abe62d3fd6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe9def770a8b3108cf6351abe62d3fd6 = L.map(
#                 &quot;map_fe9def770a8b3108cf6351abe62d3fd6&quot;,
#                 {
#                     center: [28.5634, -80.5768],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d84cae6cb88e4a2b50cb62421da33c5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3d84cae6cb88e4a2b50cb62421da33c5.addTo(map_fe9def770a8b3108cf6351abe62d3fd6);
#
#
#             var marker_8b8e15225fe7d46d2349e29ca074460c = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_fe9def770a8b3108cf6351abe62d3fd6);
#
#
#             var icon_f1e52a3570ec40de49a91f5d88f0d140 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_8b8e15225fe7d46d2349e29ca074460c.setIcon(icon_f1e52a3570ec40de49a91f5d88f0d140);
#
#
#         var popup_8554c76314398bcdd7b2745f870be9a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52a8c5f1c17892a2dd0e601b1f5b517a = $(`&lt;div id=&quot;html_52a8c5f1c17892a2dd0e601b1f5b517a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site: CCAFS LC-40&lt;br&gt;Success: 0&lt;/div&gt;`)[0];
#                 popup_8554c76314398bcdd7b2745f870be9a8.setContent(html_52a8c5f1c17892a2dd0e601b1f5b517a);
#
#
#
#         marker_8b8e15225fe7d46d2349e29ca074460c.bindPopup(popup_8554c76314398bcdd7b2745f870be9a8)
#         ;
#
#
#
#
#             var marker_d2f9633c4ac9a9915966bcae2b0235ea = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_fe9def770a8b3108cf6351abe62d3fd6);
#
#
#             var icon_2bedfb8ba30d87a278f7efcbf1af8ec0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_d2f9633c4ac9a9915966bcae2b0235ea.setIcon(icon_2bedfb8ba30d87a278f7efcbf1af8ec0);
#
#
#         var popup_bfba169d1f411a164749b1a8223fac90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7eaa86425d8dc9d1cbf234b5e96aeec0 = $(`&lt;div id=&quot;html_7eaa86425d8dc9d1cbf234b5e96aeec0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site: CCAFS LC-40&lt;br&gt;Success: 0&lt;/div&gt;`)[0];
#                 popup_bfba169d1f411a164749b1a8223fac90.setContent(html_7eaa86425d8dc9d1cbf234b5e96aeec0);
#
#
#
#         marker_d2f9633c4ac9a9915966bcae2b0235ea.bindPopup(popup_bfba169d1f411a164749b1a8223fac90)
#         ;
#
#
#
#
#             var marker_97a22f752745c6b6ad2badd4edd26b66 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_fe9def770a8b3108cf6351abe62d3fd6);
#
#
#             var icon_8712788b041efe9a2135cbf6fcd7fa09 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_97a22f752745c6b6ad2badd4edd26b66.setIcon(icon_8712788b041efe9a2135cbf6fcd7fa09);
#
#
#         var popup_01f6ca6238c343560851ed05c9167bb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f123bb91958908188e334c2ca8f668e = $(`&lt;div id=&quot;html_2f123bb91958908188e334c2ca8f668e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site: CCAFS LC-40&lt;br&gt;Success: 0&lt;/div&gt;`)[0];
#                 popup_01f6ca6238c343560851ed05c9167bb5.setContent(html_2f123bb91958908188e334c2ca8f668e);
#
#
#
#         marker_97a22f752745c6b6ad2badd4edd26b66.bindPopup(popup_01f6ca6238c343560851ed05c9167bb5)
#         ;

# %% [markdown]
# Your updated map with distance line should look like the following screenshot:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_distance.png">
# </center>

# %% [markdown]
# *TODO:* Similarly, you can draw a line betwee a launch site to its closest city, railway, highway, etc. You need to use `MousePosition` to find the their coordinates on the map first

# %% [markdown]
# A railway map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/railway.png">
# </center>

# %% [markdown]
# A highway map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/highway.png">
# </center>

# %% [markdown]
# A city map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/city.png">
# </center>

# %%
# Create a marker with distance to a closest city, railway, highway, etc.
# Draw a line between the marker to the launch site

# %% [markdown]
# After you plot distance lines to the proximities, you can answer the following questions easily:
#
# *   Are launch sites in close proximity to railways?
# *   Are launch sites in close proximity to highways?
# *   Are launch sites in close proximity to coastline?
# *   Do launch sites keep certain distance away from cities?
#
# Also please try to explain your findings.

# %% [markdown]
# # Next Steps:
#
# Now you have discovered many interesting insights related to the launch sites' location using folium, in a very interactive way. Next, you will need to build a dashboard using Ploty Dash on detailed launch records.

# %% [markdown]
# ## Authors

# %% [markdown]
# [Pratiksha Verma](https://www.linkedin.com/in/pratiksha-verma-6487561b1/)

# %% [markdown]
# <!--## Change Log--!>

# %% [markdown]
# <!--| Date (YYYY-MM-DD) | Version | Changed By      | Change Description      |
# | ----------------- | ------- | -------------   | ----------------------- |
# | 2022-11-09        | 1.0     | Pratiksha Verma | Converted initial version to Jupyterlite|--!>

# %% [markdown]
# ### <h3 align="center"> IBM Corporation 2022. All rights reserved. <h3/>
